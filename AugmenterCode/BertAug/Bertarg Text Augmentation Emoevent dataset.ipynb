# %%
! pip install transformers==4.10.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.10.1
#   Downloading transformers-4.10.1-py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (3.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (23.1)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 44.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (2022.10.31)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 33.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.1) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.1) (2023.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (2.0.12)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.10.1) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.10.1) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.10.1) (1.2.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=3bbc8edbc24419399aac5659277398b800becf20b0c8bf76e225e09b6ddb5c06
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 sacremoses-0.0.53 tokenizers-0.10.3 transformers-4.10.1

# %% [markdown]
# # **Data**

# %% [markdown]
# # Emo Event dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

emoevent_train_csv_path = '/content/drive/MyDrive/Colab Notebooks/datasets/emoevent_train.csv'
emoevent_dev_csv_path = '/content/drive/MyDrive/Colab Notebooks/datasets/emoevent_test.csv'

emoevent_train = pd.read_csv(emoevent_train_csv_path)
emoevent_dev = pd.read_csv(emoevent_dev_csv_path)

# %%
print('emoevent_train shape:', emoevent_train.shape)
emoevent_train['tweet'].head(10)
# Out:
# emoevent_train shape: (5112, 2)
# 0    What is one thing that you can not live withou...
# 1    Hahahhaha bells will be ringing to show solida...
# 2    The Compassionate Civilization Collaborative (...
# 3    They say much was spared, but the images of HA...
# 4    "I may be small. I may be a girl, but I won’t ...
# 5    HASHTAG Today we have begun the definitive pha...
# 6    "The highest education is that which does not ...
# 7    “Hi Friends! Lots of people are making comment...
# 8    HASHTAG election: socialist party HASHTAG decl...
# 9    THAT EPISODE WAS FUCKING EVERYTHING... 🤯🤯🤯🤯🤯 H...
# Name: tweet, dtype: object

# %%
emoevent_train['emotion'].head(10)
# Out:
# 0    4
# 1    0
# 2    2
# 3    5
# 4    4
# 5    3
# 6    4
# 7    4
# 8    4
# 9    3
# Name: emotion, dtype: int64

# %%
X_train = emoevent_train['tweet']
y_train = emoevent_train['emotion']

X_test = emoevent_dev['tweet']
y_test = emoevent_dev['emotion']

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5112,)
# (5112,)
# (2191,)
# (2191,)

# %%
# label: 'sadness': 0, 'neutral': 6, 'fear': 2, 'anger': 3, 'disgust': 4, 'surprise': 5, 'joy': 6
y_train.value_counts()
# Out:
# 4    2313
# 3    1427
# 1     536
# 5     291
# 0     274
# 6     165
# 2     106
# Name: emotion, dtype: int64

# %%
y_test.value_counts()
# Out:
# 4    992
# 3    612
# 1    229
# 5    125
# 0    118
# 6     70
# 2     45
# Name: emotion, dtype: int64

# %% [markdown]
# # **Model**

# %%
# Fit and transform X_train using Tfidf Vectorizer with default parameters
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train).toarray()
print('tfidf train shape:', X_train_tfidf.shape)
print('tfidf train type:', X_train_tfidf.dtype)

X_test_tfidf = vectorizer.transform(X_test).toarray()
print('tfidf test:', X_test_tfidf.shape)
# Out:
# tfidf train shape: (5112, 9912)
# tfidf train type: float64
# tfidf test: (2191, 9912)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC().fit(X_train_tfidf, y_train)

from sklearn import metrics
predicted = clf.predict(X_test_tfidf)

acc = metrics.accuracy_score(y_test, predicted)
print('accuracy is: ', acc*100)

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,predicted))
print('\n')
print(classification_report(y_test,predicted))
# Out:
# accuracy is:  53.40027384755819
# [[  5  21   0   6  83   2   1]
#  [ 14  48   2  21 138   4   2]
#  [  1   3   1   3  36   1   0]
#  [  0   7   0 354 239   8   4]
#  [ 19  47   3 194 712  15   2]
#  [  4   8   0  12  53  47   1]
#  [  1   3   0  15  47   1   3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.11      0.04      0.06       118
#            1       0.35      0.21      0.26       229
#            2       0.17      0.02      0.04        45
#            3       0.59      0.58      0.58       612
#            4       0.54      0.72      0.62       992
#            5       0.60      0.38      0.46       125
#            6       0.23      0.04      0.07        70
#
#     accuracy                           0.53      2191
#    macro avg       0.37      0.28      0.30      2191
# weighted avg       0.50      0.53      0.50      2191

# %% [markdown]
# # Augmentation using Bertarg

# %%
! pip install nlpaug==1.1.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nlpaug==1.1.7
#   Downloading nlpaug-1.1.7-py3-none-any.whl (405 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 19.6 MB/s eta 0:00:00
# Installing collected packages: nlpaug
# Successfully installed nlpaug-1.1.7

# %%
# apply augmentation to the train data and save the results into a file
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as naf

from nlpaug.util import Action
import nlpaug.flow as naf

aug_bert = naf.Sequential([naf.Sometimes([
    naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="insert", device ='cuda')]),
    naf.Sometimes([naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="substitute", device ='cuda')
])])
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

data = {'text': X_train, 'label': y_train}
base_train = pd.DataFrame.from_dict(data)
base_train.shape
# Out:
# (5112, 2)

# %%
rep = 5 # how many repetitions of the record


bert_train = base_train.copy()
bert_train['paraphrase'] = bert_train['text'].progress_apply(lambda x:aug_bert.augment(x, rep))
bert_train = bert_train.explode('paraphrase').reset_index(drop=True)
# Out:
#   0%|          | 0/5112 [00:00<?, ?it/s]

# %%
bert_train.head(20)
# Out:
#                                                  text  label  \
# 0   What is one thing that you can not live withou...      4
# 1   What is one thing that you can not live withou...      4
# 2   What is one thing that you can not live withou...      4
# 3   What is one thing that you can not live withou...      4
# 4   What is one thing that you can not live withou...      4
# 5   Hahahhaha bells will be ringing to show solida...      0
# 6   Hahahhaha bells will be ringing to show solida...      0
# 7   Hahahhaha bells will be ringing to show solida...      0
# 8   Hahahhaha bells will be ringing to show solida...      0
# 9   Hahahhaha bells will be ringing to show solida...      0
# 10  The Compassionate Civilization Collaborative (...      2
# 11  The Compassionate Civilization Collaborative (...      2
# 12  The Compassionate Civilization Collaborative (...      2
# 13  The Compassionate Civilization Collaborative (...      2
# 14  The Compassionate Civilization Collaborative (...      2
# 15  They say much was spared, but the images of HA...      5
# 16  They say much was spared, but the images of HA...      5
# 17  They say much was spared, but the images of HA...      5
# 18  They say much was spared, but the images of HA...      5
# 19  They say much was spared, but the images of HA...      5
#
#                                            paraphrase
# 0   his help will one thing gone that children can...
# 1   now! one thing that you can not part without? ...
# 2   what is which one thing. that nowadays you can...
# 3   what be h truly 1 rare thing that you can not ...
# 4   what is essentially one thing that you can rat...
# 5   & hahahhaha bells will absolutely be down ring...
# 6   hahahhaha bells would say ringing to show soli...
# 7   what hahahhaha bells will truly be ringing to ...
# 8   hahahhaha done up? will be ringing to show sol...
# 9   more bells will be ringing to show solidarity ...
# 10  2009 alien civilization collaborative ( nasa )...
# 11  the higher civilization leadership ( mission c...
# 12  the compassionate civilization collaborative (...
# 13  ( total civilization 3 ( c3 ) award declared t...
# 14  the compassionate communities collaborative ( ...
# 15  they say which much was spared, but the haunti...
# 16  they say much more was taken, - but the idea o...
# 17  records quite say since this was spared, but t...
# 18  they learnt much battle was left, in the news ...
# 19  historians say much that spared, but the image...

# %% [markdown]
# # Model with augmented train data (paraphrased data)

# %%
# Fit and transform X_train using Tfidf Vectorizer with default parameters
from sklearn.feature_extraction.text import TfidfVectorizer

# !! we should concatenate original train with paraphrased train
new_data = X_train.append(bert_train['paraphrase'])

vectorizer = TfidfVectorizer() #max_features=3000)
X_train_tfidf = vectorizer.fit_transform(new_data).toarray() #bert_train['paraphrase']).toarray()
print('tfidf train shape:', X_train_tfidf.shape)
print('tfidf train type:', X_train_tfidf.dtype)

X_test_tfidf = vectorizer.transform(X_test).toarray()
print('tfidf test:', X_test_tfidf.shape)
# Out:
# <ipython-input-18-a0cc4121832e>:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_data = X_train.append(bert_train['paraphrase'])
# tfidf train shape: (30672, 16490)
# tfidf train type: float64
# tfidf test: (2191, 16490)

# %%
from sklearn.svm import LinearSVC

# !! we should concatenate original labels with paraphrased text labels
new_labels = y_train.append(bert_train['label'])

clf = LinearSVC().fit(X_train_tfidf, new_labels) # bert_train['label'])

from sklearn import metrics
predicted = clf.predict(X_test_tfidf)

acc = metrics.accuracy_score(y_test, predicted)
print('accuracy is: ', acc*100)

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,predicted))
print('\n')
print(classification_report(y_test,predicted))
# Out:
# <ipython-input-19-c339a40fefc5>:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_labels = y_train.append(bert_train['label'])
# accuracy is:  50.52487448653583
# [[  9  31   2   9  63   3   1]
#  [ 17  43   4  20 136   8   1]
#  [  0   2   3   1  37   2   0]
#  [  4   7   0 350 238   8   5]
#  [ 25  62   8 218 642  23  14]
#  [  4   9   0  10  47  54   1]
#  [  5   3   0  18  36   2   6]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.14      0.08      0.10       118
#            1       0.27      0.19      0.22       229
#            2       0.18      0.07      0.10        45
#            3       0.56      0.57      0.57       612
#            4       0.54      0.65      0.59       992
#            5       0.54      0.43      0.48       125
#            6       0.21      0.09      0.12        70
#
#     accuracy                           0.51      2191
#    macro avg       0.35      0.30      0.31      2191
# weighted avg       0.48      0.51      0.49      2191

# %% [markdown]
# # Create CSV file from augmented dataset

# %%
# !cd '/content/drive/My Drive/Colab Notebooks/NLP Augmentation/Datasets/'
bert_train.to_csv('/content/drive/My Drive/Colab Notebooks/datasets/emoevent_BertAug_5.csv', encoding='utf-8', index=False, sep=',')
# Out:
# /bin/bash: line 0: cd: /content/drive/My Drive/Colab Notebooks/NLP Augmentation/Datasets/: No such file or directory
