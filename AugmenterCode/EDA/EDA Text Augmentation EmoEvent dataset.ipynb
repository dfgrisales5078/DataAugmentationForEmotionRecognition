# %%
! pip install transformers==4.10.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.10.1
#   Downloading transformers-4.10.1-py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (2022.10.31)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (23.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (4.65.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 45.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 14.9 MB/s eta 0:00:00
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (3.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.10.1) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.1) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.1) (2023.4.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.10.1) (1.26.15)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.10.1) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.10.1) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.10.1) (1.2.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=64d1b769317534856a2b5a755ee84172fc25882b863ba98f680351873882d67d
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 sacremoses-0.0.53 tokenizers-0.10.3 transformers-4.10.1

# %% [markdown]
# # **Data**

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 20.2 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.14.1)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 10.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (23.1.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.9.1

# %% [markdown]
# # Emo Event dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


emoevent_train_csv_path = '/content/drive/MyDrive/Colab Notebooks/emoevent_train.csv'
emoevent_dev_csv_path = '/content/drive/MyDrive/Colab Notebooks/emoevent_test.csv'

emoevent_train = pd.read_csv(emoevent_train_csv_path)
emoevent_dev = pd.read_csv(emoevent_dev_csv_path)

# %%
print('emoevent_train shape:', emoevent_train.shape)
emoevent_train.head(10)
# Out:
# emoevent_train shape: (5112, 2)
#                                                tweet  emotion
# 0  What is one thing that you can not live withou...        4
# 1  Hahahhaha bells will be ringing to show solida...        0
# 2  The Compassionate Civilization Collaborative (...        2
# 3  They say much was spared, but the images of HA...        5
# 4  "I may be small. I may be a girl, but I won’t ...        4
# 5  HASHTAG Today we have begun the definitive pha...        3
# 6  "The highest education is that which does not ...        4
# 7  “Hi Friends! Lots of people are making comment...        4
# 8  HASHTAG election: socialist party HASHTAG decl...        4
# 9  THAT EPISODE WAS FUCKING EVERYTHING... 🤯🤯🤯🤯🤯 H...        3

# %%
print('emoevent_train shape:', emoevent_train.shape)
emoevent_dev.head(10)
# Out:
# emoevent_train shape: (5112, 2)
#                                                tweet  emotion
# 0  Queen of Peace, look kindly upon the people an...        4
# 1  Very sad to see, as HASHTAG The French people ...        5
# 2  And they said Virgil Van Dijk is the best defe...        4
# 3  “The books that the world calls immoral are bo...        4
# 4  A short-circuit in the electrical system is mo...        4
# 5  US National Security advisor HASHTAG says that...        4
# 6  Theon, you're a good man. Thank you. HASHTAG H...        3
# 7  HASHTAG the baddest bitch in westeros HASHTAG ...        4
# 8  Let's take a moment to thank Melisandra for li...        3
# 9  HASHTAG Have you been troubled by your life? I...        4

# %%
emoevent_train['emotion'].head(10)
# Out:
# 0    4
# 1    0
# 2    2
# 3    5
# 4    4
# 5    3
# 6    4
# 7    4
# 8    4
# 9    3
# Name: emotion, dtype: int64

# %%
X_train = emoevent_train['tweet']
y_train = emoevent_train['emotion']

X_test = emoevent_dev['tweet']
y_test = emoevent_dev['emotion']

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5112,)
# (5112,)
# (2191,)
# (2191,)

# %%
# label: 'others': 0, 'joy': 6, 'disgust': 2, 'sadness': 3, 'anger': 4, 'surprise': 5, 'fear': 6
y_train.value_counts()
# Out:
# 4    2313
# 3    1427
# 1     536
# 5     291
# 0     274
# 6     165
# 2     106
# Name: emotion, dtype: int64

# %%
y_test.value_counts()
# Out:
# 4    992
# 3    612
# 1    229
# 5    125
# 0    118
# 6     70
# 2     45
# Name: emotion, dtype: int64

# %% [markdown]
# # **Model**

# %%
# Fit and transform X_train using Tfidf Vectorizer with default parameters
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train).toarray()
print('tfidf train shape:', X_train_tfidf.shape)
print('tfidf train type:', X_train_tfidf.dtype)

X_test_tfidf = vectorizer.transform(X_test).toarray()
print('tfidf test:', X_test_tfidf.shape)
# Out:
# tfidf train shape: (5112, 9912)
# tfidf train type: float64
# tfidf test: (2191, 9912)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC().fit(X_train_tfidf, y_train)

from sklearn import metrics
predicted = clf.predict(X_test_tfidf)

acc = metrics.accuracy_score(y_test, predicted)
print('accuracy is: ', acc*100)

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,predicted))
print('\n')
print(classification_report(y_test,predicted))
# Out:
# accuracy is:  53.40027384755819
# [[  5  21   0   6  83   2   1]
#  [ 14  48   2  21 138   4   2]
#  [  1   3   1   3  36   1   0]
#  [  0   7   0 354 239   8   4]
#  [ 19  47   3 194 712  15   2]
#  [  4   8   0  12  53  47   1]
#  [  1   3   0  15  47   1   3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.11      0.04      0.06       118
#            1       0.35      0.21      0.26       229
#            2       0.17      0.02      0.04        45
#            3       0.59      0.58      0.58       612
#            4       0.54      0.72      0.62       992
#            5       0.60      0.38      0.46       125
#            6       0.23      0.04      0.07        70
#
#     accuracy                           0.53      2191
#    macro avg       0.37      0.28      0.30      2191
# weighted avg       0.50      0.53      0.50      2191

# %% [markdown]
# # Augmentation using EDA

# %%
! pip install nlpaug==1.1.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nlpaug==1.1.7
#   Downloading nlpaug-1.1.7-py3-none-any.whl (405 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: nlpaug
# Successfully installed nlpaug-1.1.7

# %%
# apply augmentation to the train data and save the results into a file
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as naf

from nlpaug.util import Action
import nlpaug.flow as naf

aug_eda = naf.Sequential([
    naf.Sometimes([naw.RandomWordAug(action="swap")]),
    naf.Sometimes([naw.RandomWordAug(action="delete")]),
    naf.Sometimes([naw.SynonymAug(aug_src='wordnet')])
])

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

data = {'text': X_train, 'label': y_train}
base_train = pd.DataFrame.from_dict(data)
base_train.shape
# Out:
# (5112, 2)

# %%
rep = 5 # how many repetitions of the record


eda_train = base_train.copy()
eda_train['paraphrase'] = eda_train['text'].progress_apply(lambda x:aug_eda.augment(x, rep))
eda_train = eda_train.explode('paraphrase').reset_index(drop=True)
# Out:
#   0%|          | 0/5112 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-470bcbf04e2f> in <cell line: 5>()
#       3
#       4 eda_train = base_train.copy()
# ----> 5 eda_train['paraphrase'] = eda_train['text'].progress_apply(lambda x:aug_eda.augment(x, rep))
#       6 eda_train = eda_train.explode('paraphrase').reset_index(drop=True)
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     803                 # on the df using our wrapper (which provides bar updating)
#     804                 try:
# --> 805                     return getattr(df, df_function)(wrapper, **kwargs)
#     806                 finally:
#     807                     t.close()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     798                     # take a fast or slow code path; so stop when t.total==t.n
#     799                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 800                     return func(*args, **kwargs)
#     801
#     802                 # Apply the provided function (in **kwargs)
#
# <ipython-input-18-470bcbf04e2f> in <lambda>(x)
#       3
#       4 eda_train = base_train.copy()
# ----> 5 eda_train['paraphrase'] = eda_train['text'].progress_apply(lambda x:aug_eda.augment(x, rep))
#       6 eda_train = eda_train.explode('paraphrase').reset_index(drop=True)
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/flow/pipeline.py in augment(self, data, n, num_thread)
#      56             augmented_results = []
#      57             if num_thread == 1:
# ---> 58                 augmented_results = [self._augment(data) for _ in range(n)]
#      59             else:
#      60                 if self.device == 'cpu':
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/flow/pipeline.py in <listcomp>(.0)
#      56             augmented_results = []
#      57             if num_thread == 1:
# ---> 58                 augmented_results = [self._augment(data) for _ in range(n)]
#      59             else:
#      60                 if self.device == 'cpu':
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/flow/pipeline.py in _augment(self, data, n, num_thread)
#     101             aug.include_detail = parent_include_detail  # Follow parent setting
#     102             aug.parent_change_seq = self.parent_change_seq+len(change_logs)
# --> 103             augmented_data = aug.augment(augmented_data, n=n, num_thread=num_thread)
#     104             if aug.include_detail:
#     105                 # (augmented_data, change_log)
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/flow/pipeline.py in augment(self, data, n, num_thread)
#      56             augmented_results = []
#      57             if num_thread == 1:
# ---> 58                 augmented_results = [self._augment(data) for _ in range(n)]
#      59             else:
#      60                 if self.device == 'cpu':
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/flow/pipeline.py in <listcomp>(.0)
#      56             augmented_results = []
#      57             if num_thread == 1:
# ---> 58                 augmented_results = [self._augment(data) for _ in range(n)]
#      59             else:
#      60                 if self.device == 'cpu':
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/flow/pipeline.py in _augment(self, data, n, num_thread)
#     101             aug.include_detail = parent_include_detail  # Follow parent setting
#     102             aug.parent_change_seq = self.parent_change_seq+len(change_logs)
# --> 103             augmented_data = aug.augment(augmented_data, n=n, num_thread=num_thread)
#     104             if aug.include_detail:
#     105                 # (augmented_data, change_log)
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/base_augmenter.py in augment(self, data, n, num_thread)
#     114                 # Single Thread
#     115                 if num_thread == 1:
# --> 116                     augmented_results = [action_fx(clean_data) for _ in range(n)]
#     117
#     118                 # Multi Thread
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/base_augmenter.py in <listcomp>(.0)
#     114                 # Single Thread
#     115                 if num_thread == 1:
# --> 116                     augmented_results = [action_fx(clean_data) for _ in range(n)]
#     117
#     118                 # Multi Thread
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/augmenter/word/synonym.py in substitute(self, data)
#     135             else:
#     136                 for word_pos in word_poses:
# --> 137                     candidates.extend(self.model.predict(pos[aug_idx][0], pos=word_pos))
#     138
#     139             candidates = [c for c in candidates if c.lower() != original_token.lower()]
#
# /usr/local/lib/python3.9/dist-packages/nlpaug/model/word_dict/wordnet.py in predict(self, word, pos)
#      38     def predict(self, word, pos=None):
#      39         results = []
# ---> 40         for synonym in self.model.synsets(word, pos=pos, lang=self.lang):
#      41             for lemma in synonym.lemmas(lang=self.lang):
#      42                 if self.is_synonym:
#
# /usr/local/lib/python3.9/dist-packages/nltk/corpus/reader/wordnet.py in synsets(self, lemma, pos, lang, check_exceptions)
#    1755             if pos is None:
#    1756                 pos = POS_LIST
# -> 1757             return [
#    1758                 get_synset(p, offset)
#    1759                 for p in pos
#
# /usr/local/lib/python3.9/dist-packages/nltk/corpus/reader/wordnet.py in <listcomp>(.0)
#    1756                 pos = POS_LIST
#    1757             return [
# -> 1758                 get_synset(p, offset)
#    1759                 for p in pos
#    1760                 for form in self._morphy(lemma, p, check_exceptions)
#
# /usr/local/lib/python3.9/dist-packages/nltk/corpus/reader/wordnet.py in synset_from_pos_and_offset(self, pos, offset)
#    1557             and line_offset == f"{'0'*(8-len(str(offset)))}{str(offset)}"
#    1558         ):
# -> 1559             synset = self._synset_from_pos_and_line(pos, data_file_line)
#    1560             assert synset._offset == offset
#    1561             self._synset_offset_cache[pos][offset] = synset
#
# /usr/local/lib/python3.9/dist-packages/nltk/corpus/reader/wordnet.py in _synset_from_pos_and_line(self, pos, data_file_line)
#    1626             for _ in range(n_pointers):
#    1627                 symbol = _next_token()
# -> 1628                 offset = int(_next_token())
#    1629                 pos = _next_token()
#    1630                 lemma_ids_str = _next_token()
#
# KeyboardInterrupt:

# %%
eda_train.head(20)
# Out:
#                                                  text  label  \
# 0   What is one thing that you can not live withou...      4
# 1   What is one thing that you can not live withou...      4
# 2   What is one thing that you can not live withou...      4
# 3   What is one thing that you can not live withou...      4
# 4   What is one thing that you can not live withou...      4
# 5   Hahahhaha bells will be ringing to show solida...      0
# 6   Hahahhaha bells will be ringing to show solida...      0
# 7   Hahahhaha bells will be ringing to show solida...      0
# 8   Hahahhaha bells will be ringing to show solida...      0
# 9   Hahahhaha bells will be ringing to show solida...      0
# 10  The Compassionate Civilization Collaborative (...      2
# 11  The Compassionate Civilization Collaborative (...      2
# 12  The Compassionate Civilization Collaborative (...      2
# 13  The Compassionate Civilization Collaborative (...      2
# 14  The Compassionate Civilization Collaborative (...      2
# 15  They say much was spared, but the images of HA...      5
# 16  They say much was spared, but the images of HA...      5
# 17  They say much was spared, but the images of HA...      5
# 18  They say much was spared, but the images of HA...      5
# 19  They say much was spared, but the images of HA...      5
#
#                                            paraphrase
# 0   What is i thing that you can not live without?...
# 1   What matchless thing you can live? — Easy, uni...
# 2   What is unrivaled that can non live without? E...
# 3   Is that you can not live without? — Easy, HASH...
# 4   Is what one thing you without? — Easy, HASHTAG...
# 5   Hahahhaha bells be exhibit solidarity for HASH...
# 6   Hahahhaha bells be ringing solidarity for HASH...
# 7   Hahahhaha bells bequeath be to present for HAS...
# 8   Bells will be show HASHTAG! Been telling for p...
# 9   Hahahhaha bells will ringing be show to solida...
# 10  The Compassionate Collaborative Civilization (...
# 11  The Compassionate Civilization Collaborative (...
# 12  The Compassionate Collaborative (C3) has decla...
# 13  The Civilization Collaborative () declared a /...
# 14  The Civilisation Collaborative (C3) climate / ...
# 15  They say much was spared, images HASHTAG up in...
# 16  They a great deal say spar was but, the of ima...
# 17  Say they much be spared, simply of images the ...
# 18  They say much was spared, only the images of H...
# 19  Say they much spared was, the but images of up...

# %% [markdown]
# # Model with augmented train data (paraphrased data)

# %%
# Fit and transform X_train using Tfidf Vectorizer with default parameters
from sklearn.feature_extraction.text import TfidfVectorizer

# !! we should concatenate original train with paraphrased train
new_data = X_train.append(eda_train['paraphrase'])

vectorizer = TfidfVectorizer() #max_features=3000)
X_train_tfidf = vectorizer.fit_transform(new_data).toarray() #eda_train['paraphrase']).toarray()
print('tfidf train shape:', X_train_tfidf.shape)
print('tfidf train type:', X_train_tfidf.dtype)

X_test_tfidf = vectorizer.transform(X_test).toarray()
print('tfidf test:', X_test_tfidf.shape)
# Out:
# <ipython-input-26-32f711c08426>:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_data = X_train.append(eda_train['paraphrase'])
# tfidf train shape: (30672, 15143)
# tfidf train type: float64
# tfidf test: (2191, 15143)

# %%
from sklearn.svm import LinearSVC
# !! we should concatenate original labels with paraphrased text labels
new_labels = y_train.append(eda_train['label'])

clf = LinearSVC().fit(X_train_tfidf, new_labels) # eda_train['label'])

from sklearn import metrics
predicted = clf.predict(X_test_tfidf)

acc = metrics.accuracy_score(y_test, predicted)
print('accuracy is: ', acc*100)

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,predicted))
print('\n')
print(classification_report(y_test,predicted))
# Out:
# <ipython-input-27-e631ece76bc9>:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_labels = y_train.append(eda_train['label'])
# accuracy is:  49.88589685075308
# [[ 12  22   1   9  69   4   1]
#  [ 15  57   3  18 128   6   2]
#  [  1   3   2   4  34   1   0]
#  [  0  11   0 337 244  14   6]
#  [ 24  73   6 227 632  21   9]
#  [  3  12   0  10  52  47   1]
#  [  5   4   0  13  38   4   6]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.20      0.10      0.13       118
#            1       0.31      0.25      0.28       229
#            2       0.17      0.04      0.07        45
#            3       0.55      0.55      0.55       612
#            4       0.53      0.64      0.58       992
#            5       0.48      0.38      0.42       125
#            6       0.24      0.09      0.13        70
#
#     accuracy                           0.50      2191
#    macro avg       0.35      0.29      0.31      2191
# weighted avg       0.47      0.50      0.48      2191

# %% [markdown]
# # Create CSV file from augmented dataset

# %%
# !cd '/content/drive/My Drive/Colab Notebooks/'
eda_train.to_csv('/content/drive/My Drive/Colab Notebooks/EmoEvent_EdaAug_5.csv', encoding='utf-8', index=False, sep=',')
