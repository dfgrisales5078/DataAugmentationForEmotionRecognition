# %% [markdown]
# # **Data**

# %% [markdown]
# # WASSA all dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

wassa_train_csv_path = '/content/drive/My Drive/WASSA_train_all.csv'
wassa_dev_csv_path = '/content/drive/My Drive/WASSA_dev_all.csv'

wassa_train = pd.read_csv(wassa_train_csv_path)
wassa_dev = pd.read_csv(wassa_dev_csv_path)

# %%
print('wassa_train shape:', wassa_train.shape)
wassa_train['essay'].head(10)
# Out:
# wassa_train shape: (1860, 2)
# 0    it is really diheartening to read about these ...
# 1    the phone lines from the suicide prevention li...
# 2    no matter what your heritage, you should be ab...
# 3    it is frightening to learn about all these sha...
# 4    the eldest generation of russians aren't being...
# 5    middle east is fucked up, I've honestly never ...
# 6    well first of all whoever wrote this article d...
# 7    well well well, look at what we have well, the...
# 8    just another fucked up mental sickness of amer...
# 9    it seems a horny male college student has fina...
# Name: essay, dtype: object

# %%
wassa_train['emotion'].head(10)
# Out:
# 0    0
# 1    0
# 2    6
# 3    2
# 4    0
# 5    3
# 6    3
# 7    4
# 8    3
# 9    4
# Name: emotion, dtype: int64

# %%
X_train = wassa_train['essay']
y_train = wassa_train['emotion']

X_test = wassa_dev['essay']
y_test = wassa_dev['emotion']

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1860,)
# (1860,)
# (270,)
# (270,)

# %%
# label: 'sadness': 0, 'neutral': 6, 'fear': 2, 'anger': 3, 'disgust': 4, 'surprise': 5, 'joy': 6
y_train.value_counts()
# Out:
# 0    647
# 3    349
# 6    275
# 2    194
# 5    164
# 4    149
# 1     82
# Name: emotion, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    98
# 3    76
# 2    31
# 6    25
# 1    14
# 5    14
# 4    12
# Name: emotion, dtype: int64

# %% [markdown]
# # **Model**

# %%
# Fit and transform X_train using Tfidf Vectorizer with default parameters
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train).toarray()
print('tfidf train shape:', X_train_tfidf.shape)
print('tfidf train type:', X_train_tfidf.dtype)

X_test_tfidf = vectorizer.transform(X_test).toarray()
print('tfidf test:', X_test_tfidf.shape)
# Out:
# tfidf train shape: (1860, 9688)
# tfidf train type: float64
# tfidf test: (270, 9688)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC().fit(X_train_tfidf, y_train)

from sklearn import metrics
predicted = clf.predict(X_test_tfidf)

acc = metrics.accuracy_score(y_test, predicted)
print('accuracy is: ', acc*100)

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,predicted))
print('\n')
print(classification_report(y_test,predicted))
# Out:
# accuracy is:  47.40740740740741
# [[76  1  6  7  1  2  5]
#  [ 6  0  1  3  1  1  2]
#  [10  1 16  0  1  1  2]
#  [35  0  0 27  7  2  5]
#  [ 5  0  0  4  1  0  2]
#  [ 6  0  0  4  1  2  1]
#  [ 8  1  1  7  2  0  6]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.78      0.62        98
#            1       0.00      0.00      0.00        14
#            2       0.67      0.52      0.58        31
#            3       0.52      0.36      0.42        76
#            4       0.07      0.08      0.08        12
#            5       0.25      0.14      0.18        14
#            6       0.26      0.24      0.25        25
#
#     accuracy                           0.47       270
#    macro avg       0.33      0.30      0.31       270
# weighted avg       0.45      0.47      0.45       270

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

data = {'text': X_train, 'label': y_train}
base_train = pd.DataFrame.from_dict(data)
base_train.shape
# Out:
# (1860, 2)

# %%
base_train.shape
# Out:
# (1860, 2)

# %% [markdown]
# # ChatGPT API Augmentation test

# %%
# !pip install --upgrade setuptools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (67.6.1)

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.4-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 5.9 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 16.1 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 10.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.4 yarl-1.8.2

# %%
rep = 5
chatgpt_train = base_train.copy()

# %%
import openai
import pandas as pd
import time

openai.api_key = "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"

def augment_text(text):

    prompt = (f"Paraphrase this sentence: '{text}'. "
          "Your paraphrased version should be grammatically correct and semantically equivalent.")
    
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=60,
        n=5,
        stop=None,
        temperature=0.7,
    )

    responses = []
    for i in range(5):
      responses.append(response.choices[i].text.strip())
    time.sleep(3)
    return responses

# %%
chatgpt_train['paraphrase'] = chatgpt_train['text'].progress_apply(lambda x:augment_text(x))
chatgpt_train = chatgpt_train.explode('paraphrase').reset_index(drop=True)
# Out:
#   0%|          | 0/1860 [00:00<?, ?it/s]

# %%
chatgpt_train.head(50)
# Out:
#                                                  text  label  \
# 0   it is really diheartening to read about these ...      0
# 1   it is really diheartening to read about these ...      0
# 2   it is really diheartening to read about these ...      0
# 3   it is really diheartening to read about these ...      0
# 4   it is really diheartening to read about these ...      0
# 5   the phone lines from the suicide prevention li...      0
# 6   the phone lines from the suicide prevention li...      0
# 7   the phone lines from the suicide prevention li...      0
# 8   the phone lines from the suicide prevention li...      0
# 9   the phone lines from the suicide prevention li...      0
# 10  no matter what your heritage, you should be ab...      6
# 11  no matter what your heritage, you should be ab...      6
# 12  no matter what your heritage, you should be ab...      6
# 13  no matter what your heritage, you should be ab...      6
# 14  no matter what your heritage, you should be ab...      6
# 15  it is frightening to learn about all these sha...      2
# 16  it is frightening to learn about all these sha...      2
# 17  it is frightening to learn about all these sha...      2
# 18  it is frightening to learn about all these sha...      2
# 19  it is frightening to learn about all these sha...      2
# 20  the eldest generation of russians aren't being...      0
# 21  the eldest generation of russians aren't being...      0
# 22  the eldest generation of russians aren't being...      0
# 23  the eldest generation of russians aren't being...      0
# 24  the eldest generation of russians aren't being...      0
# 25  middle east is fucked up, I've honestly never ...      3
# 26  middle east is fucked up, I've honestly never ...      3
# 27  middle east is fucked up, I've honestly never ...      3
# 28  middle east is fucked up, I've honestly never ...      3
# 29  middle east is fucked up, I've honestly never ...      3
# 30  well first of all whoever wrote this article d...      3
# 31  well first of all whoever wrote this article d...      3
# 32  well first of all whoever wrote this article d...      3
# 33  well first of all whoever wrote this article d...      3
# 34  well first of all whoever wrote this article d...      3
# 35  well well well, look at what we have well, the...      4
# 36  well well well, look at what we have well, the...      4
# 37  well well well, look at what we have well, the...      4
# 38  well well well, look at what we have well, the...      4
# 39  well well well, look at what we have well, the...      4
# 40  just another fucked up mental sickness of amer...      3
# 41  just another fucked up mental sickness of amer...      3
# 42  just another fucked up mental sickness of amer...      3
# 43  just another fucked up mental sickness of amer...      3
# 44  just another fucked up mental sickness of amer...      3
# 45  it seems a horny male college student has fina...      4
# 46  it seems a horny male college student has fina...      4
# 47  it seems a horny male college student has fina...      4
# 48  it seems a horny male college student has fina...      4
# 49  it seems a horny male college student has fina...      4
#
#                                            paraphrase
# 0   It is really upsetting to read about these imm...
# 1   It's very upsetting to read about these immigr...
# 2   It is very upsetting to read about these immig...
# 3   It is really upsetting to read about these imm...
# 4   I was really upset to read about the immigrant...
# 5   The suicide prevention hotline saw an increase...
# 6   After the election, the suicide prevention lin...
# 7   After the election, the number of phone calls ...
# 8   The suicide prevention line received more call...
# 9   After the election, the number of phone calls ...
# 10  No matter what your heritage is, you should be...
# 11  No matter what your heritage is, you should be...
# 12  No matter what your heritage, you should be ab...
# 13  No matter what your heritage is, you should be...
# 14  It shouldn't matter what your heritage is, you...
# 15  It is frightening to learn about all these sha...
# 16  The large number of shark attacks is worrying,...
# 17  It is frightening to learn about all these sha...
# 18  It is frightening to learn about all these sha...
# 19  Although it is scary to read about all of the ...
# 20  The elderly generation of Russians is not bein...
# 21  The elderly in Russia are not being treated we...
# 22  The eldest generation of Russians is not being...
# 23  The Russians who are the elders are not being ...
# 24  The elderly generation of Russians is not bein...
# 25  The Middle East is messed up and I've never he...
# 26  The middle east is in a bad state, I've never ...
# 27  The Middle East is in a bad state and I've nev...
# 28  The Middle East is messed up. I've never heard...
# 29  The Middle East is a mess - I've never heard o...
# 30  The person who wrote this article does not kno...
# 31  First of all, whoever wrote this article doesn...
# 32  The article is not divided properly into parag...
# 33  First of all, the person who wrote this articl...
# 34  Whoever wrote this article did not divide it i...
# 35  Well well well, look at what we have here. The...
# 36  "Well, well, well, look at what we have here. ...
# 37  "Well, well, well, look at what we have here. ...
# 38  "Well, well, well. Look at what we have here. ...
# 39  "Well, well, well. Look at what we have here. ...
# 40  Just another example of the police using exces...
# 41  just another example of police brutality again...
# 42  Just another example of the American police's ...
# 43  The police in America are fucked up for shooti...
# 44  I honestly have no idea why American police ar...
# 45  It seems that a horny male college student has...
# 46  It seems that a horny male college student has...
# 47  It seems that a horny male college student has...
# 48  It seems that a horny male college student has...
# 49  It seems a male college student has finally ta...

# %% [markdown]
# # Model with augmented train data (paraphrased data)

# %%
# Fit and transform X_train using Tfidf Vectorizer with default parameters
from sklearn.feature_extraction.text import TfidfVectorizer

# !! we should concatenate original train with paraphrased train
new_data = X_train.append(chatgpt_train['paraphrase'])

vectorizer = TfidfVectorizer() #max_features=3000)
X_train_tfidf = vectorizer.fit_transform(new_data).toarray() #chatgpt_train['paraphrase']).toarray()
print('tfidf train shape:', X_train_tfidf.shape)
print('tfidf train type:', X_train_tfidf.dtype)

X_test_tfidf = vectorizer.transform(X_test).toarray()
print('tfidf test:', X_test_tfidf.shape)
# Out:
# <ipython-input-19-0375d623d0ed>:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_data = X_train.append(chatgpt_train['paraphrase'])
# tfidf train shape: (11160, 10833)
# tfidf train type: float64
# tfidf test: (270, 10833)

# %%
from sklearn.svm import LinearSVC

# !! we should concatenate original labels with paraphrased text labels
new_labels = y_train.append(chatgpt_train['label'])

clf = LinearSVC().fit(X_train_tfidf, new_labels) # chatgpt_train['label'])

from sklearn import metrics
predicted = clf.predict(X_test_tfidf)

acc = metrics.accuracy_score(y_test, predicted)
print('accuracy is: ', acc*100)

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,predicted))
print('\n')
print(classification_report(y_test,predicted))
# Out:
# <ipython-input-20-6113aa645902>:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_labels = y_train.append(chatgpt_train['label'])
# accuracy is:  48.51851851851852
# [[74  1  4  8  3  4  4]
#  [ 6  2  0  5  0  0  1]
#  [ 9  0 18  3  0  1  0]
#  [35  0  2 27  5  1  6]
#  [ 3  0  0  5  2  0  2]
#  [ 5  0  1  5  0  2  1]
#  [ 7  1  0  7  3  1  6]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.76      0.62        98
#            1       0.50      0.14      0.22        14
#            2       0.72      0.58      0.64        31
#            3       0.45      0.36      0.40        76
#            4       0.15      0.17      0.16        12
#            5       0.22      0.14      0.17        14
#            6       0.30      0.24      0.27        25
#
#     accuracy                           0.49       270
#    macro avg       0.41      0.34      0.36       270
# weighted avg       0.47      0.49      0.46       270

# %%
# !cd '/content/drive/My Drive/Colab Notebooks/NLP Augmentation/Datasets/'
chatgpt_train.to_csv('/content/drive/My Drive/Colab Notebooks/NLP Augmentation/Datasets/wassa_all_chatgptaug_5.csv', encoding='utf-8', index=False, sep=',')
